# %% [markdown]
# <a href="https://colab.research.google.com/github/hytis333/python-scraping-kadai/blob/main/kadai_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pprint
from getpass import getpass

api_key = getpass('APIキーを入力してください：')

search_word = input('検索する駅を入力してください:')

url = 'https://maps.googleapis.com/maps/api/geocode/json'

response = requests.get(
    url,
    params={
        'address': search_word,
        'key': api_key
    }
)

json_data = response.json()
#pprint.pprint(json_data)
location_lat=''
location_lng=''
for result in json_data['results']:
  map_info = result['address_components'][0]['short_name']
  location_lat = result['geometry']['location']['lat']
  location_lng = result['geometry']['location']['lng']



url2 = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword={search_word}&location={location_lat}%2C{location_lng}&radius=300&language=japanese&type=restaurant&key={api_key}'
response2 = requests.get(url2)

json_data2 = response2.json()
#pprint.pprint(json_data2)

for result in json_data2['results']:
  print(f"{result['name']} {result['rating']}
        {result['vicinity']}")
# Out:
# APIキーを入力してください：··········
# 検索する駅を入力してください:東京駅
# Station Restaurant The Central 4 Chiyoda City, Marunouchi, 1 Chome−9−1 グランスタ東京地下 ホーム1 JR東日本東京駅構内
# T’s Tantan 4.5 Chiyoda City, Marunouchi, 1 Chome−9−1 JR東日本改札内 グランスタ東京1F 京葉ストリートエリア内
# Tamatoya 4.7 Chiyoda City, Marunouchi, 1 Chome−9−1 東京駅 黒塀横丁B1F
# Blanc Rouge 4.4 Chiyoda City, Marunouchi, 1 Chome−9−1 東京ステーションホテル 2F
# Toyoken Tokyo Station 3.9 Chiyoda City, Marunouchi, 1 Chome−9−1 B1F
# Yonezawa Gyu Oki 4.1 地下一階, 千代田区丸の内１丁目９−１ グランスタ八重北内 黒塀横丁, 1 Chome-9-1 Marunouchi, Chiyoda City
# Mugi to Tamago Tokyo Station Yaesu North Exit 4.1 Chiyoda City, Marunouchi, 1 Chome−9−1 １F JR東日本東京駅構内（改札外）グランスタ 八重北
# Hamburg Works 3.8 Chiyoda City, Marunouchi, 1 Chome−9−1 階 グランスタ八重洲内 東京駅 Yaesu Underground Central Exit
# Hageten 3.7 Chiyoda City, Marunouchi, 1 Chome−9−1 東京駅グランスタ八重北１階 八重北食堂内
# Dancyu shokudo 3.8 Chiyoda City, Marunouchi, 1 Chome−9−1 グランスタ八重北 1F Yaekita Shokudo
# Sobaichi 3.7 千代田区丸の内１丁目９−１ JR 東京駅 1F 丸の内･八重洲北口改札内 クランスタ東京 吹き抜けエリア
# ...

# %%
import requests
import pprint
from getpass import getpass

api_key = getpass('APIキーを入力してください：')

search_word = input('検索する駅を入力してください:')

url = 'https://maps.googleapis.com/maps/api/geocode/json'

response = requests.get(
    url,
    params={
        'address': search_word,
        'key': api_key
    }
)

json_data = response.json()
# pprint.pprint(json_data)
location_lat=''
location_lng=''
for result in json_data['results']:
  map_info = result['address_components'][0]['short_name']
  location_lat = result['geometry']['location']['lat']
  location_lng = result['geometry']['location']['lng']

url2 = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword={search_word}&location={location_lat}%2C{location_lng}&radius=300&language=japanese&type=restaurant&key={api_key}'
response2 = requests.get(url2)

json_data2 = response2.json()
pprint.pprint(json_data2)

for result in json_data2['results']:
  print(f"{result['name']} {result['rating']} {result['vicinity']}")
# Out:
# APIキーを入力してください：··········
# 検索する駅を入力してください:東京駅
# {'html_attributions': [],
#  'next_page_token': 'AUc7tXVdYSrwDqQfGIGCfF6bs5yv4zNFCjDCvGSK2_jEGkE2AW8DqrpwT8pexOsziylUImzHwn7KSrppKm3sHSHrt1tJrV4TdejEyvubgcBw9j4iWKwqBBLRKXz5uy2le0P5b1y0PuiCpxfvBGPo4fq1I38wqDj5c-q57OqTBEDHslUfJ5QPDXhZ-8cGjNQeJUUe6zWQTW1ZWtujx_ZdDUTr-x_brMJlCilGnSp_jTDVmVC8vcZRuqerSGLQwo-IvLaIRy_7e62vtlBJkMs5x3UXoEvk-T_my33_nRBN-UgJWQBfyuPeHKnpzQU2AOGF2Dk1_17Cpj8s9SU0P4_E4SGx-1PL-CUfdj2VLdySCirypD-V7AxqYA3R5NDhb_Q2kT5Z-kt17JroOE8ANjG_iW2z8GYI-Pr6ROE2qnm6khQCRnNWgu2UHiA9HXndfRig1lKvwcYyzybpSuA',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6822913, 'lng': 139.7681488},
#                            'viewport': {'northeast': {'lat': 35.68402662989273,
#                                                       'lng': 139.7689307},
#                                         'southwest': {'lat': 35.68132697010729,
# ...

# %% [markdown]
# \
